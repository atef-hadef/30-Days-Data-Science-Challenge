# %% [markdown]
# # Day 27 — Streamlit Deploy

# %% [markdown]
# ## 1. Import Libraries

# %% [markdown]
# ## 2. Load Data

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %% [markdown]
# ## 5. Modeling / Analysis

# %% [markdown]
# ## 6. Insights & Conclusions
